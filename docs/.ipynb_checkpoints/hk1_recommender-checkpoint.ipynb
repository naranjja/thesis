# %%
import pandas as pd

# %%
df1 = pd.read_csv('hk1_initial_pass_results.csv')
df2 = pd.read_csv('hk1_uncertain_pass_results.csv')

# %%
df1 = df1[df1['score'] != 'uncertain']

# %%
df = pd.concat([df1, df2])
df = df.sort_values('score', ascending=False)
df
# Out:
#                          Unnamed: 0  extra_trees  random_forest  lightgbm  \
# 8                        D__Soltero     0.412614       0.330065  0.256359
# 17                       pregunta_1     0.220797       0.264314  0.420486
# 11                      pregunta_12     0.364672       0.287223  0.316854
# 10  D__ASESOR COMERCIAL FUNCIONARIO     0.360566       0.309267  0.304677
# 9      D__ASESOR COMERCIAL JUNIOR 1     0.412892       0.307579  0.274797
# 14                      D__Femenino     0.373952       0.292461  0.279288
# 7                       pregunta_28     0.369146       0.251093  0.382445
# 6                           cluster     0.342611       0.330067  0.330067
# 13                      pregunta_20     0.388072       0.189336  0.380415
# 16                             Edad     0.309977       0.301529  0.319186
# 15       D__ASESOR COMERCIAL MASTER     0.353659       0.261152  0.317372
# 18                       pregunta_5     0.276821       0.355064  0.270306
# 19                      pregunta_11     0.305891       0.383060  0.212057
# 20                        D__Casado     0.399504       0.252589  0.244485
# 21                      pregunta_23     0.279640       0.266364  0.348505
# 22                       pregunta_4     0.272833       0.307125  0.306275
# 23                      pregunta_21     0.340560       0.208944  0.323029
# 24                      pregunta_16     0.261015       0.349292  0.246471
# 25                      pregunta_14     0.229801       0.355752  0.265729
# 26                       pregunta_2     0.225301       0.335229  0.261282
# 12                       pregunta_6     0.183348       0.399568  0.382790
# 0                       pregunta_27     0.459334       0.295620  0.360034
# 1                        pregunta_8     0.421464       0.393661  0.251350
# 2                       pregunta_18     0.350897       0.418774  0.293105
# 3                       pregunta_17     0.327237       0.258175  0.466905
# 4                        pregunta_9     0.251325       0.392931  0.372988
# 5                      D__Masculino     0.443072       0.275533  0.291983
# 0                       pregunta_13     0.340487       0.431288  0.361171
# 1        D__ASESOR COMERCIAL SENIOR     0.493961       0.263141  0.239141
# 8                          D__Otros     0.333077       0.234370  0.272096
# 7                         ingresoef     0.376125       0.230853  0.251166
# 6                           cluster     0.363875       0.265119  0.231952
# 5                       pregunta_10     0.332049       0.210393  0.330799
# 4                       pregunta_30     0.313069       0.325663  0.305464
# 3      D__ASESOR COMERCIAL JUNIOR 2     0.460616       0.274777  0.218750
# 2                       pregunta_29     0.380090       0.275369  0.303205
# 27                       pregunta_3     0.287578       0.345550  0.172677
# 28                      pregunta_22     0.307175       0.247641  0.239951
# 29                      pregunta_25     0.197472       0.164004  0.238699
# 42                      pregunta_26     0.152710       0.150851  0.237952
# 41                      pregunta_19     0.129306       0.174088  0.245468
# 40                      pregunta_24     0.216567       0.156916  0.177094
# 39                      pregunta_15     0.264053       0.169697  0.205860
# 38                       pregunta_7     0.263639       0.195284  0.191583
#
#              score
# 8        uncertain
# 17       uncertain
# 11       uncertain
# 10       uncertain
# 9        uncertain
# 14       uncertain
# 7        uncertain
# 6        uncertain
# 13       uncertain
# 16       uncertain
# 15       uncertain
# 18       uncertain
# 19       uncertain
# 20       uncertain
# 21       uncertain
# 22       uncertain
# 23       uncertain
# 24       uncertain
# 25       uncertain
# 26       uncertain
# 12       uncertain
# 0   good_uncertain
# 1   good_uncertain
# 2   good_uncertain
# 3   good_uncertain
# 4   good_uncertain
# 5   good_uncertain
# 0             good
# 1             good
# 8             good
# 7             good
# 6             good
# 5             good
# 4             good
# 3             good
# 2             good
# 27   bad_uncertain
# 28   bad_uncertain
# 29   bad_uncertain
# 42             bad
# 41             bad
# 40             bad
# 39             bad
# 38             bad
