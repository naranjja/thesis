# %%
import pandas as pd

# %%
df1 = pd.read_csv('hk1_initial_pass_results.csv')
df2 = pd.read_csv('hk1_uncertain_pass_results.csv')

# %%
df1 = df1[df1['score'] != 'uncertain']

# %%
df = pd.concat([df1, df2])
df = df.sort_values('score', ascending=False)
df
# Out:
#                          Unnamed: 0  extra_trees  random_forest  lightgbm  \
# 7                         D__Casado     0.413473       0.343696  0.259617
# 17                      pregunta_20     0.300569       0.277719  0.347058
# 10                       pregunta_6     0.412938       0.341728  0.233041
# 9                       pregunta_17     0.267039       0.331072  0.399398
# 8                         ingresoef     0.444488       0.289045  0.275112
# 13  D__ASESOR COMERCIAL FUNCIONARIO     0.364047       0.279190  0.322766
# 6                           cluster     0.345446       0.338597  0.336215
# 12       D__ASESOR COMERCIAL MASTER     0.362158       0.313240  0.295869
# 15                     D__Masculino     0.387158       0.249959  0.309318
# 16                       pregunta_8     0.409422       0.306022  0.226326
# 14                       pregunta_2     0.260652       0.342410  0.345604
# 18                       D__Soltero     0.422833       0.258283  0.244121
# ...
