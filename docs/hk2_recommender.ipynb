# %%
import pandas as pd

# %%
df1 = pd.read_csv('hk2_initial_pass_results.csv')
df2 = pd.read_csv('hk2_uncertain_pass_results.csv')

# %%
df1 = df1[df1['score'] != 'uncertain']

# %%
df = pd.concat([df1, df2])
df = df.sort_values('score', ascending=False)
df
# Out:
#                          Unnamed: 0  extra_trees  random_forest  lightgbm  \
# 12                         D__Otros     0.339060       0.247223  0.268264
# 23                      pregunta_10     0.226951       0.286482  0.255939
# 17           nEntidades_competencia     0.316450       0.264762  0.222266
# 16         nAmonestacion_suspension     0.352522       0.227570  0.239262
# 15                       D__Soltero     0.312493       0.276123  0.246513
# 14                     Amonestacion     0.324133       0.272291  0.248902
# 13                        ingresoef     0.377897       0.244274  0.231965
# 20                      pregunta_26     0.263488       0.197459  0.321157
# 11                          cluster     0.410282       0.224075  0.222337
# 10                      pregunta_11     0.346107       0.204418  0.318637
# 9                       D__Femenino     0.387318       0.266197  0.229587
# 19         nPorcentaje_sal_cero_cuo     0.230115       0.310236  0.243970
# ...
