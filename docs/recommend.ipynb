# %%
import pandas as pd

# %%
df1 = pd.read_csv('initial_pass_results.csv')
df2 = pd.read_csv('uncertain_pass_results.csv')

# %%
df1 = df1[df1['score'] != 'uncertain']
df1
# Out:
#                          Unnamed: 0  extra_trees  random_forest  lightgbm  \
# 0                      nOperaciones     0.426680       0.434579  0.785667
# 1              nporcentaje_Herencia     0.222851       0.301117  0.416732
# 2      D__ASESOR COMERCIAL JUNIOR 1     0.312834       0.182451  0.255131
# 3        D__ASESOR COMERCIAL SENIOR     0.279777       0.227137  0.237655
# 4                              D__R     0.286725       0.207676  0.222024
# 5                          herencia     0.300565       0.202497  0.205267
# 6                      D__Masculino     0.293972       0.197366  0.213645
# 7        D__ASESOR COMERCIAL MASTER     0.284264       0.232504  0.188139
# 8                           cluster     0.234239       0.236708  0.230402
# 9                      Amonestacion     0.276925       0.222248  0.196889
# 10  D__ASESOR COMERCIAL FUNCIONARIO     0.262063       0.231826  0.201078
# 11               nProductividad_dic     0.292630       0.191045  0.209456
# ...

# %%
df = pd.concat([df1, df2])
df = df.sort_values('score', ascending=False)
df
# Out:
#                          Unnamed: 0  extra_trees  random_forest  lightgbm  \
# 12                             D__U     0.293158       0.219979  0.270643
# 23           nEntidades_competencia     0.183758       0.237820  0.234504
# 17                       pregunta_2     0.219155       0.169550  0.335330
# 16                      pregunta_18     0.253632       0.176939  0.309500
# 15                      pregunta_10     0.278054       0.230027  0.232578
# 14                      D__Femenino     0.260905       0.280104  0.221476
# 13         nAmonestacion_suspension     0.270267       0.268264  0.224762
# 20                             Edad     0.153880       0.248831  0.281518
# 11                       D__Soltero     0.268819       0.253984  0.261014
# 10                      pregunta_30     0.329465       0.254535  0.250931
# 9          nPorcentaje_sal_cero_cuo     0.269841       0.313888  0.263959
# 19                       pregunta_6     0.290828       0.170517  0.251497
# ...
